# %% [markdown]
# <a href="https://colab.research.google.com/github/mfletcher2021/blogcode/blob/main/IP_addresses_pt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Installing the ipaddress package</h2>

# %%
# !pip install ipaddress
# Out:
# Collecting ipaddress
#   Downloading ipaddress-1.0.23-py2.py3-none-any.whl.metadata (923 bytes)
# Downloading ipaddress-1.0.23-py2.py3-none-any.whl (18 kB)
# Installing collected packages: ipaddress
# Successfully installed ipaddress-1.0.23

# %% [markdown]
# <h2>IP Boolean Magic</h2>

# %%
import ipaddress

ip1 = ipaddress.ip_address('192.168.1.1')
ip2 = ipaddress.ip_address('192.168.2.1')
ip3 = ipaddress.ip_address('192.168.3.1')
ip4 = ipaddress.ip_address('192.168.1.2')
ip5 = ipaddress.ip_address('192.168.1.3')

print(ip1 < ip2)
print(ip3 > ip2)
print(ip1 < ip4)
print(ip5 > ip4)
# Out:
# True
# True
# True
# True

# %% [markdown]
# <h2>IP arithmetic</h2>

# %%
print(ipaddress.IPv4Address(u'175.122.13.23') + 18)
print(ipaddress.IPv4Address(u'144.123.100.12') - 15)
print(ipaddress.IPv4Address(u'255.255.255.255') + 1)
print(ipaddress.IPv4Address(u'0.0.0.0') - 1)
# Out:
# 175.122.13.41
# 144.123.99.253
# ---------------------------------------------------------------------------
# AddressValueError                         Traceback (most recent call last)
# /tmp/ipython-input-675658766.py in <cell line: 0>()
#       1 print(ipaddress.IPv4Address(u'175.122.13.23') + 18)
#       2 print(ipaddress.IPv4Address(u'144.123.100.12') - 15)
# ----> 3 print(ipaddress.IPv4Address(u'255.255.255.255') + 1)
#       4 print(ipaddress.IPv4Address(u'0.0.0.0') - 1)
#
# /usr/lib/python3.12/ipaddress.py in __add__(self, other)
#     597         if not isinstance(other, int):
#     598             return NotImplemented
# --> 599         return self.__class__(int(self) + other)
#     600
#     601     def __sub__(self, other):
#
# /usr/lib/python3.12/ipaddress.py in __init__(self, address)
#    1302         # Efficient constructor from integer.
#    1303         if isinstance(address, int):
# -> 1304             self._check_int_address(address)
#    1305             self._ip = address
#    1306             return
#
# /usr/lib/python3.12/ipaddress.py in _check_int_address(self, address)
#     419         if address > self._ALL_ONES:
#     420             msg = "%d (>= 2**%d) is not permitted as an IPv%d address"
# --> 421             raise AddressValueError(msg % (address, self._max_prefixlen,
#     422                                            self._version))
#     423
#
# AddressValueError: 4294967296 (>= 2**32) is not permitted as an IPv4 address

# %% [markdown]
# <h2>Sorting IPs</h2>

# %%
listOfIPs = ['0.0.0.0', '12.15.33.19', '12.15.34.19', '182.105.99.84', '182.106.100.85', '255.255.255.255']
sorted([ipaddress.ip_address(address) for address in listOfIPs])
# Out:
# [IPv4Address('0.0.0.0'),
#  IPv4Address('12.15.33.19'),
#  IPv4Address('12.15.34.19'),
#  IPv4Address('182.105.99.84'),
#  IPv4Address('182.106.100.85'),
#  IPv4Address('255.255.255.255')]
